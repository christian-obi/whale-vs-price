# %% [markdown]
# ### testing dunesim api key with balance calls

# %%
import os
import requests
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Get API key from environment variable
api_key = os.getenv("DUNESIM_API_KEY")

url = "https://api.sim.dune.com/v1/evm/balances/0xd8da6bf26964af9d7eed9e03e53415d37aa96045"

headers = {"X-Sim-Api-Key": api_key}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"request_time":"2025-08-06T13:04:12.530877750+00:00","response_time":"2025-08-06T13:04:12.752002231+00:00","wallet_address":"0xd8da6bf26964af9d7eed9e03e53415d37aa96045","balances":[{"chain":"ethereum","chain_id":1,"address":"0x0e36c45d16585d1801e37cfaa577a9ad39f9343a","amount":"45787557175393926414790300082","symbol":"Kendu","name":"Kendu of Bank","decimals":18,"price_usd":9.418175373140437e20,"value_usd":4.312352433855548e31,"pool_size":941.8175373140416,"low_liquidity":true},{"chain":"ethereum","chain_id":1,"address":"0x1014f52e5e33e50f0b0ac3c69cd007424f0c92b1","amount":"2881430034316536249911829519904","symbol":"PEPEF","name":"pepefork.vip","decimals":18,"price_usd":2.509230345300009e18,"value_usd":7.230171679965899e30,"pool_size":2.5092303453000038,"low_liquidity":true},{"chain":"ethereum","chain_id":1,"address":"0x133b8f31aba904294a95cd6477633b593f019818","amount":"767387143779415173800484933","symbol":"BMW","name":"BMW Metaverse","decimals":18,"price_usd":4.109083218945404e19,
# ...

# %% [markdown]
# #### Getting Dune whale transaction on arbitrum token
#
# whale tx value  defined as tx volume > 100k
# ARB CA "0x912ce59144191c1204e64559fe8253a0e49e6548"
